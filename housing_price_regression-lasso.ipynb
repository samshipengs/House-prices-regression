# %%
# Adding needed libraries and reading data
import pandas as pd
import numpy as np
from scipy.stats import skew
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
# rcParams['figure.figsize'] = 22, 4
import time

import seaborn as sns
from sklearn import metrics, ensemble, tree, linear_model
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.utils import shuffle

# import xgboost as xgb

from fancyimpute import BiScaler, KNN, NuclearNormMinimization, SoftImpute, MICE


# Load data
train_df = pd.read_csv('./data/train.csv')
test_df = pd.read_csv('./data/test.csv')
train_y = train_df.pop('SalePrice') # take out y value
test_id = test_df.pop('Id') # for writing submission file
# also remove id column from train as it will not be used
train_df.drop('Id', axis = 1, inplace=True)
# Out:
# Using cuDNN version 5105 on context None
# Mapped name None to device cuda: GeForce GTX 1080 (0000:01:00.0)

# %%
train_df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig      ...       ScreenPorch PoolArea PoolQC  \
# 0         Lvl    AllPub    Inside      ...                 0        0    NaN
# 1         Lvl    AllPub       FR2      ...                 0        0    NaN
# 2         Lvl    AllPub    Inside      ...                 0        0    NaN
# 3         Lvl    AllPub    Corner      ...                 0        0    NaN
# 4         Lvl    AllPub       FR2      ...                 0        0    NaN
#
#   Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0   NaN         NaN       0       2    2008        WD         Normal
# 1   NaN         NaN       0       5    2007        WD         Normal
# 2   NaN         NaN       0       9    2008        WD         Normal
# 3   NaN         NaN       0       2    2006        WD        Abnorml
# 4   NaN         NaN       0      12    2008        WD         Normal
#
# [5 rows x 79 columns]

# %%
print train_df.shape
print test_df.shape
# Out:
# (1460, 79)
# (1459, 79)

# %%
# check number of nan in both train and test for each columns
def check_null(df):
    null_check = df.isnull().sum(axis=0)
    null = null_check[null_check!=0]
    null_df = df.isnull()
    return null, null_df
train_null, _ = check_null(train_df)
test_null, _ = check_null(test_df)
# print ">>>null value in train:\n", train_null
# print "\n>>>null value in test:\n", test_null

# %%
# get rid off columns with missing values more than 15%
drop_cols1 = [train_null.index[i] for i in range(train_null.shape[0]) if train_null.values[i] > train_df.shape[0]*0.15]
drop_cols2 = [test_null.index[i] for i in range(test_null.shape[0]) if test_null.values[i] > test_df.shape[0]*0.15]
drop_cols = list(set(drop_cols1+drop_cols2))
print drop_cols
# Out:
# ['Fence', 'LotFrontage', 'MiscFeature', 'Alley', 'FireplaceQu', 'PoolQC']

# %%
# finish drop and start impute rest missing data
train_df.drop(drop_cols, axis = 1, inplace=True)
test_df.drop(drop_cols, axis = 1, inplace=True)

# after dropping selected columns, we want to impute which requires
# data to be numeric value, so we proceed to convert categorical data
# but this conversion erases nan, so here we record where the nan is
_, train_nulls = check_null(train_df)
_, test_nulls = check_null(test_df)

# %%
# convert object to categorical value first
# record what columns are categorical and numeric columns
obj_columns = train_df.select_dtypes(['object']).columns
num_columns = list(set(train_df.columns)-set(obj_columns))

# just in case test set has more categories than train, concatenate them first for conversion
train_df.loc[:, 'temp'] = 'train'
test_df.loc[:, 'temp'] = 'test'
combined_df = pd.concat([train_df, test_df])

for col in obj_columns:
    combined_df[col] = combined_df[col].astype('category')
# now convert train set
combined_df[obj_columns] = combined_df[obj_columns].apply(lambda x: x.cat.codes)

# now split back to train and test
train_df = combined_df[combined_df['temp']=='train'].drop(['temp'], axis=1)
test_df = combined_df[combined_df['temp']=='test'].drop(['temp'], axis=1)

# %%
# get the nan back
train_df[train_nulls] = np.nan
test_df[test_nulls] = np.nan

# %%
# impute missing data

# train_filled = SimpleFill().complete(train_df)
train_filled = SoftImpute().complete(train_df)
# train_filled = KNN(k=5).complete(train_df)
# train_filled = MICE().complete(train_df)

test_filled = SoftImpute().complete(test_df)
# test_filled = KNN(k=5).complete(test_df)

train_filled = pd.DataFrame(train_filled, columns=train_df.columns)
test_filled = pd.DataFrame(test_filled, columns=test_df.columns)
# Out:
# [SoftImpute] Max Singular Value of X_init = 569789.981335
# [SoftImpute] Iter 1: observed MAE=33.994852 rank=7
# [SoftImpute] Iter 2: observed MAE=33.857168 rank=6
# [SoftImpute] Iter 3: observed MAE=33.522605 rank=6
# [SoftImpute] Iter 4: observed MAE=33.451014 rank=6
# [SoftImpute] Iter 5: observed MAE=33.434150 rank=6
# [SoftImpute] Iter 6: observed MAE=33.430075 rank=6
# [SoftImpute] Iter 7: observed MAE=33.429086 rank=6
# [SoftImpute] Stopped after iteration 7 for lambda=11395.799627
# [SoftImpute] Max Singular Value of X_init = 449871.284960
# [SoftImpute] Iter 1: observed MAE=29.863629 rank=8
# [SoftImpute] Iter 2: observed MAE=29.953122 rank=8
# [SoftImpute] Iter 3: observed MAE=29.638571 rank=7
# [SoftImpute] Iter 4: observed MAE=29.519348 rank=7
# [SoftImpute] Iter 5: observed MAE=29.491556 rank=7
# [SoftImpute] Iter 6: observed MAE=29.484741 rank=7
# [SoftImpute] Iter 7: observed MAE=29.483045 rank=7
# [SoftImpute] Stopped after iteration 7 for lambda=8997.425699

# %%
# Our SalesPrice is skewed right (check plot below). I'm logtransforming it. 
ax = sns.distplot(train_y)

# %%
## we can log transform y value
ax = sns.distplot(np.log1p(train_y))
train_y = np.log1p(train_y)

# %%
# Similarly, look at other numeric features
rcParams['figure.figsize'] = 20, 20
# take a look of each variable vs y
print "number of numeric columns: ", len(num_columns)
f, axes = plt.subplots(5,7)
n_iter = 0
for i in range(5):
    for j in range(7):
        sns.distplot(train_filled[num_columns[n_iter]],ax=axes[i][j])
        n_iter += 1
# Out:
# number of numeric columns:  35

# %% [markdown]
# ### Skewness

# %%
# compute skewness aloong column/feature
skewed_fts = train_filled[num_columns].apply(lambda x: skew(x), axis=0) 
skewed_fts = skewed_fts[np.abs(skewed_fts) > 0.75]
skewed_fts = skewed_fts.index

train_filled[skewed_fts] = np.log1p(train_filled[skewed_fts])
test_filled[skewed_fts] = np.log1p(test_filled[skewed_fts])
# now take a look again
f, axes = plt.subplots(5,7)
n_iter = 0
for i in range(5):
    for j in range(7):
        sns.distplot(train_filled[num_columns[n_iter]],ax=axes[i][j])
        n_iter += 1

# %%
# Standarization
# fisrt option: standarize non-categoorical values
# std_features = list(set(train_filled.columns)-set(obj_columns))
# ss = StandardScaler(copy=True, with_mean=True, with_std=True)
# train_filled[std_features] = ss.fit_transform(train_filled[std_features])
# test_filled[std_features] = ss.transform(test_filled[std_features])

# second option: standarize all values
ss = StandardScaler(copy=True, with_mean=True, with_std=True)
train_filled[train_filled.columns] = ss.fit_transform(train_filled)
test_filled[test_filled.columns] = ss.transform(test_filled)

# %%
# train_filled[num_columns].describe()

# %%
# train_filled[num_columns].head()

# %%
rcParams['figure.figsize'] = 20, 20
# take a look of each variable vs y
f, axes = plt.subplots(5,7)
n_iter = 0
for i in range(5):
    for j in range(7):
        sns.regplot(x=train_filled[num_columns[n_iter]], y=train_y,ax=axes[i][j])
        n_iter += 1

# %% [markdown]
# ### multicollinearity

# %%
# look at correlations
correlations = train_filled.corr()
cor_abs = np.abs(correlations)
cor_pair = cor_abs[(cor_abs>0.5) & (cor_abs != 1)].unstack().dropna().to_dict()
print "Total pair number:", len(correlations)*(len(correlations)-1)/2
cor_sort = sorted(cor_pair, key=cor_pair.get)[::-1]
cor_value = [cor_pair[k] for k in cor_sort]
cor_df = pd.DataFrame({'pair':cor_sort, 'cor': cor_value})
cor_df.drop_duplicates(subset='cor', inplace=True)
print "Correlated pairs(abs>0.5): ", cor_df.shape[0]
cor_df.head(10)
# Out:
# Total pair number: 2628
# Correlated pairs(abs>0.5):  38
#          cor                          pair
# 0   0.882475      (GarageCars, GarageArea)
# 2   0.854163    (Exterior2nd, Exterior1st)
# 4   0.843164    (BsmtFinType2, BsmtFinSF2)
# 6   0.825521     (GrLivArea, TotRmsAbvGrd)
# 8   0.774360    (BsmtFinSF1, BsmtFinType1)
# 10  0.676620  (TotRmsAbvGrd, BedroomAbvGr)
# 12  0.667936     (GarageYrBlt, GarageCars)
# 14  0.653167         (FullBath, GrLivArea)
# 16  0.641584      (ExterQual, KitchenQual)
# 18  0.634842       (Foundation, YearBuilt)

# %%
ax = sns.pairplot(train_filled[['GarageArea', 'GarageCars']])

# %%
# from above we choose some features to discard
cor_freq = pd.DataFrame({'fts': [x for pair in cor_df['pair'].values for x in pair]})
cor_freq['fts'].value_counts().plot(kind='bar', figsize=(8,6))

# %%
# drop some of the features
freq_fts = list(cor_freq['fts'].value_counts()[:10].index)
top_cor = [pair for pair in cor_df['pair'][:10].values]
drop_fts = ['GarageCars', 'Exterior1st', 'BsmtFinType2', 'GarageYrBlt', 'LotFrontage', 'FullBath']

# comment out below if not dropping
# train_filled.drop(drop_fts, axis=1, inplace=True)
# test_filled.drop(drop_fts, axis=1, inplace=True)

# %% [markdown]
# ### Try PCA

# %%
# due to multicollinearity, perform PCA on dataset and see if result improves
# n_features = train_filled.shape[1]
# print "Total number of features before PCA: ", n_features

# pca = PCA(n_features)
# pca.fit_transform(train_filled)

# explained = pca.explained_variance_ratio_
# n_use = 60
# print "Covers {} variance".format(sum(explained[:n_use]))

# pca = PCA(n_use)
# train_filled = pca.fit_transform(train_filled)
# test_filled = pca.transform(test_filled)

# %% [markdown]
# ### train GB regressor

# %%
def find_params(train_X, train_Y, test_X, params_found=False, verbose=False):
    if not params_found:
        print "Finding params ..."
        t1 = time.time()
        param_grid = {'loss': ['ls', 'lad', 'huber'], 
                      'learning_rate':[0.1, 0.05, 0.02, 0.01],
                      'max_depth': [3,4,6],
                      'min_samples_leaf': [3,5,9,17],
                      'max_features': [0.1, 0.3, 1.0]}
        est = ensemble.GradientBoostingRegressor(n_estimators=5000)
        gs_cv = GridSearchCV(est, param_grid, cv=KFold(n_splits=4), n_jobs=4).fit(train_X, train_Y)
        t2 = time.time()

        print "Total time used: {}min".format((t2-t1)/60.)
        print gs_cv.best_score_
        print gs_cv.best_params_
        return gs_cv.best_params_
    else:
        print "Use previous found best params."
    
bg_param = find_params(train_filled.values, train_y.values, test_filled.values, params_found=False, verbose=True)
# find_params(train_filled, train_y.values, test_filled, params_found=True, verbose=True)
# Out:
# Finding params ...
# Total time used: 49.1783940196min
# 0.912842831405
# {'max_features': 0.1, 'loss': 'huber', 'learning_rate': 0.02, 'max_depth': 3, 'min_samples_leaf': 3}

# %%
def train_predict(train_X, train_Y, test_X, ensemble_tol=None, verbose=False):
    n_cv = 500
    prediction = []
    n_tol = 0
    for n_i in range(n_cv):
        if verbose:
            print "[CV {}]".format(n_i)
        x_train, x_val, y_train, y_val = train_test_split(train_X, train_Y, test_size=0.25, random_state=42+n_i)
        bst = ensemble.GradientBoostingRegressor(n_estimators=8000, max_features=bg_param['max_features'], 
                                                 loss=bg_param['loss'], 
                                                 learning_rate=bg_param['learning_rate'], 
                                                 max_depth=bg_param['max_depth'], 
                                                 min_samples_leaf=bg_param['min_samples_leaf'],
                                                 random_state=42+n_i)
        bst.fit(x_train, y_train)
        preds = bst.predict(x_val)
        
        preds = np.exp(preds)-1
        y_val = np.exp(y_val)-1
        r2 = metrics.r2_score(y_val, preds)
        rmsle = np.sqrt(sum((np.log(np.array(preds)+1)-np.log(np.array(y_val)+1))**2)/len(preds))
        print "r2:", r2
        print "RMSLE:", rmsle
        
        prediction_i = bst.predict(test_X)
        
        if ensemble_tol:
            if rmsle <= ensemble_tol:
                prediction.append(prediction_i)
                n_tol += 1
        else:
            prediction.append(prediction_i)
    print "Done training and predicting."
    if ensemble_tol:
        print "In total {} contributes to ensemble out of {}".format(n_tol, n_cv)
    
    prediction = np.array(prediction)
#     prediction = np.exp(np.array(prediction)) - 1
    ensemble_result = []
    n, m = prediction.shape
    p_std = np.std(prediction, axis=0) # along columns
    p_mean = np.mean(prediction, axis=0)
    for i in range(m):
        p_i = prediction[:,i]
        select_i = p_i[np.abs(p_i-p_mean[i]) < 1.*p_std[i]]
        ensemble_result.append(np.mean(select_i))
    # transform y back to normal scale
    ensemble_result = np.exp(ensemble_result) - 1
    result_df = pd.DataFrame({'Id': test_id, 'SalePrice':ensemble_result})
    result_df.to_csv('./result/result_gb8k.csv', index=False)
    
    return prediction

e_tol = 0.13
all_prediction = train_predict(train_filled.values, train_y.values, test_filled.values, ensemble_tol= e_tol, verbose=True)
# train_predict(train_filled, train_y, test_filled, verbose=True)
# r2: 0.920850022205
# RMSLE: 0.11827373148
# [CV 473]
# r2: 0.898400393767
# RMSLE: 0.121387011801
# [CV 474]
# r2: 0.867982306612
# RMSLE: 0.130866538199
# [CV 475]
# r2: 0.930956615982
# RMSLE: 0.103960974457
# [CV 476]
# r2: 0.90510063875
# RMSLE: 0.1146522853
# [CV 477]
# r2: 0.872181716037
# RMSLE: 0.112422375527
# [CV 478]
# r2: 0.869750619903
# RMSLE: 0.144025183705
# [CV 479]
# r2: 0.899549961728
# RMSLE: 0.114906475479
# [CV 480]
# r2: 0.918566656532
# RMSLE: 0.111731038851
# [CV 481]
# r2: 0.889099567627
# RMSLE: 0.117100306302
# [CV 482]
# r2: 0.917595729045
# RMSLE: 0.113321768624
# [CV 483]
# r2: 0.576093718028
# RMSLE: 0.165839463656
# [CV 484]
# r2: 0.876779367548
# RMSLE: 0.13014477692
# [CV 485]
# r2: 0.913449730221
# RMSLE: 0.115834555607
# [CV 486]
# r2: 0.930793891558
# RMSLE: 0.116208028963
# [CV 487]
# r2: 0.903941970268
# RMSLE: 0.113120379868
# [CV 488]
# r2: 0.926112900963
# RMSLE: 0.127182243279
# [CV 489]
# r2: 0.743644433109
# RMSLE: 0.146387136026
# [CV 490]
# r2: 0.917043150692
# RMSLE: 0.119552369725
# [CV 491]
# r2: 0.927655214994
# RMSLE: 0.108179457028
# [CV 492]
# r2: 0.894828365248
# RMSLE: 0.123330797827
# [CV 493]
# r2: 0.911532834152
# RMSLE: 0.119492076198
# [CV 494]
# r2: 0.928320687723
# RMSLE: 0.10085556965
# [CV 495]
# r2: 0.914619215958
# RMSLE: 0.118681890058
# [CV 496]
# r2: 0.933921457813
# RMSLE: 0.100174342188
# [CV 497]
# r2: 0.89924803892
# RMSLE: 0.1276373478
# [CV 498]
# r2: 0.91144755134
# RMSLE: 0.105978400381
# [CV 499]
# r2: 0.925887039069
# RMSLE: 0.10565662897
# Done training and predicting.
# In total 430 contributes to ensemble out of 500

# %%
# for i in all_prediction:
#     plt.plot(range(len(i)), i, 'o')

# %% [markdown]
# ### Try lasso regression

# %%
def find_params(train_X, train_Y, test_X, params_found=False, verbose=False):
    if not params_found:
        t1 = time.time()
        param_grid = {'alpha': 10**np.linspace(-6, 0, 100)}
        lasso = linear_model.Lasso(max_iter=3000)
        lasso_cv = GridSearchCV(lasso, param_grid, cv=KFold(n_splits=5, shuffle=True), 
                                n_jobs=4).fit(train_X, train_Y)
        t2 = time.time()

        cv_df = pd.DataFrame(lasso_cv.cv_results_)
        
        print "Total time used: {}min".format((t2-t1)/60.)
        print lasso_cv.best_score_
        print lasso_cv.best_params_
        
        return cv_df, lasso_cv.best_params_['alpha']
    else:
        print "Use previous found best params."
    
# find_params(train_filled.values, train_y.values, test_filled.values, params_found=True, verbose=True)
cv_df, best_alpha = find_params(train_filled.values, train_y.values, test_filled.values, params_found=False, verbose=True)
# Out:
# Total time used: 0.17536876599min
# 0.887369616084
# {'alpha': 0.0075646332755462909}

# %%
best_alpha
# Out:
# 0.0075646332755462909

# %%
rcParams['figure.figsize'] = 8, 5
plt.plot(cv_df['param_alpha'].apply(lambda x: np.log10(x)), cv_df['mean_train_score'],
         cv_df['param_alpha'].apply(lambda x: np.log10(x)), cv_df['mean_test_score'])
plt.legend(('train', 'validation'), loc='best')

# %%
def train_predict(train_X, train_Y, test_X, ensemble_tol=None, verbose=False):
    n_cv = 100
    prediction = []
    n_tol = 0
    for n_i in range(n_cv):
        if verbose:
            print "[CV {}]".format(n_i)
        x_train, x_val, y_train, y_val = train_test_split(train_X, train_Y, test_size=0.2, random_state=42+n_i)

        _, best_alpha = find_params(train_X, train_Y, test_X, params_found=False, verbose=True)
#         lm_i = linear_model.LinearRegression()
        lm_i = linear_model.Lasso(max_iter=3000, alpha=best_alpha)
        lm_i.fit(x_train, y_train)
        preds = lm_i.predict(x_val)
        
        preds = np.exp(preds)-1
        y_val = np.exp(y_val)-1
        r2 = metrics.r2_score(y_val, preds)
#         ms = metrics.mean_squared_error(y_val, preds)
        rmsle = np.sqrt(sum((np.log(np.array(preds)+1)-np.log(np.array(y_val)+1))**2)/len(preds))
        print "r2:", r2
        print "RMSLE:", rmsle
        
        prediction_i = lm_i.predict(test_X)
        
        if ensemble_tol:
            if rmsle <= ensemble_tol:
                prediction.append(prediction_i)
                n_tol += 1
        else:
            prediction.append(prediction_i)
    print "Done training and predicting."
    if ensemble_tol:
        print "In total {} contributes to ensemble out of {}".format(n_tol, n_cv)
    
    prediction = np.array(prediction)
#     prediction = np.exp(np.array(prediction)) - 1
    ensemble_result = []
    n, m = prediction.shape
    p_std = np.std(prediction, axis=0) # along columns
    p_mean = np.mean(prediction, axis=0)
    for i in range(m):
        p_i = prediction[:,i]
        select_i = p_i[np.abs(p_i-p_mean[i]) < 1.*p_std[i]]
        ensemble_result.append(np.mean(select_i))
    # transform y back to normal scale
    ensemble_result = np.exp(ensemble_result) - 1
    result_df = pd.DataFrame({'Id': test_id, 'SalePrice':ensemble_result})
    result_df.to_csv('./result/result_lasso.csv', index=False)
    
    return prediction

e_tol = 0.13
all_prediction = train_predict(train_filled.values, train_y.values, test_filled.values, ensemble_tol= e_tol, verbose=True)
# train_predict(train_filled, train_y, test_filled, verbose=True)
# Out:
# [CV 0]
# Total time used: 0.176163764795min
# 0.885890055479
# {'alpha': 4.3287612810830618e-05}
# r2: 0.897167311754
# RMSLE: 0.142542805886
# [CV 1]
# Total time used: 0.173632133007min
# 0.887358542887
# {'alpha': 0.0012328467394420659}
# r2: 0.787061692585
# RMSLE: 0.146449075007
# [CV 2]
# Total time used: 0.17208965222min
# 0.888968019765
# {'alpha': 0.0043287612810830618}
# r2: 0.893805541812
# RMSLE: 0.130146570741
# [CV 3]
# Total time used: 0.170506334305min
# 0.887059688116
# {'alpha': 0.0049770235643321137}
# r2: 0.906187219383
# RMSLE: 0.135766745685
# [CV 4]
# Total time used: 0.169179332256min
# 0.888935489687
# {'alpha': 0.0016297508346206451}
# r2: 0.898536365977
# RMSLE: 0.117702744253
# [CV 5]
# Total time used: 0.171840167046min
# 0.88734061384
# {'alpha': 0.0016297508346206451}
# r2: 0.395447167253
# RMSLE: 0.177398404941
# [CV 6]
# Total time used: 0.177337416013min
# 0.887700901079
# {'alpha': 0.0021544346900318843}
# r2: 0.550768547199
# RMSLE: 0.156614731554
# [CV 7]
# Total time used: 0.176726631323min
# 0.88558776057
# {'alpha': 0.0021544346900318843}
# r2: 0.9028733736
# RMSLE: 0.11983018399
# [CV 8]
# Total time used: 0.178574748834min
# 0.88754967502
# {'alpha': 0.0032745491628777285}
# r2: 0.905658353122
# RMSLE: 0.129813881367
# [CV 9]
# Total time used: 0.173937865098min
# 0.886278828502
# {'alpha': 0.0043287612810830618}
# r2: 0.776839092812
# RMSLE: 0.152596257186
# [CV 10]
# Total time used: 0.175208167235min
# 0.8874956961
# {'alpha': 0.0043287612810830618}
# r2: 0.909459221579
# RMSLE: 0.132922920405
# [CV 11]
# Total time used: 0.173647415638min
# 0.886787703948
# {'alpha': 0.0028480358684358021}
# r2: 0.665317942445
# RMSLE: 0.155291836137
# [CV 12]
# Total time used: 0.17877398332min
# 0.888129608805
# {'alpha': 0.001873817422860385}
# r2: 0.480452137299
# RMSLE: 0.151674633562
# [CV 13]
# Total time used: 0.175688747565min
# 0.886890042505
# {'alpha': 0.006579332246575682}
# r2: 0.796933974293
# RMSLE: 0.133926387623
# [CV 14]
# Total time used: 0.176875380675min
# 0.886991776006
# {'alpha': 0.0037649358067924675}
# r2: 0.57852987835
# RMSLE: 0.180352988501
# [CV 15]
# Total time used: 0.173787999153min
# 0.885990322391
# {'alpha': 0.0012328467394420659}
# r2: 0.56752825127
# RMSLE: 0.159442035188
# [CV 16]
# Total time used: 0.178667851289min
# 0.886640290012
# {'alpha': 0.0028480358684358021}
# r2: 0.858850074765
# RMSLE: 0.140478322127
# [CV 17]
# Total time used: 0.177103718122min
# 0.886449322151
# {'alpha': 0.0028480358684358021}
# r2: 0.786476239529
# RMSLE: 0.132909073864
# [CV 18]
# Total time used: 0.177381300926min
# 0.885784413877
# {'alpha': 0.0049770235643321137}
# r2: 0.568104593011
# RMSLE: 0.177147497563
# [CV 19]
# Total time used: 0.175616300106min
# 0.889335212911
# {'alpha': 0.0014174741629268048}
# r2: 0.871222306857
# RMSLE: 0.136697731245
# [CV 20]
# Total time used: 0.170424918334min
# 0.887089557643
# {'alpha': 0.0032745491628777285}
# r2: 0.507774582965
# RMSLE: 0.179199959828
# [CV 21]
# Total time used: 0.178983950615min
# 0.886881436028
# {'alpha': 0.0021544346900318843}
# r2: 0.913900962676
# RMSLE: 0.10156596326
# [CV 22]
# Total time used: 0.177251919111min
# 0.888547971247
# {'alpha': 0.0043287612810830618}
# r2: 0.696166003597
# RMSLE: 0.155000520146
# [CV 23]
# Total time used: 0.177313216527min
# 0.887089264727
# {'alpha': 0.0024770763559917113}
# r2: 0.918729406782
# RMSLE: 0.119022518198
# [CV 24]
# Total time used: 0.173763700326min
# 0.887503540514
# {'alpha': 0.0037649358067924675}
# r2: 0.864607028297
# RMSLE: 0.1500658056
# [CV 25]
# Total time used: 0.175240433216min
# 0.887028539261
# {'alpha': 0.0049770235643321137}
# r2: 0.895849332511
# RMSLE: 0.115168218397
# [CV 26]
# Total time used: 0.178915500641min
# 0.886456223353
# {'alpha': 0.001873817422860385}
# r2: 0.896453003818
# RMSLE: 0.135618487164
# [CV 27]
# Total time used: 0.177421565851min
# 0.886300703555
# {'alpha': 0.00026560877829466864}
# r2: 0.900595193375
# RMSLE: 0.122923806436
# [CV 28]
# Total time used: 0.178869565328min
# 0.886653377508
# {'alpha': 0.0075646332755462909}
# r2: 0.640163605987
# RMSLE: 0.160846842869
# [CV 29]
# Total time used: 0.173750817776min
# 0.886125939186
# {'alpha': 0.0037649358067924675}
# r2: 0.774451988257
# RMSLE: 0.148125054961
# [CV 30]
# Total time used: 0.182072202365min
# 0.88664493829
# {'alpha': 0.0037649358067924675}
# r2: 0.486016517417
# RMSLE: 0.150974901657
# [CV 31]
# Total time used: 0.173902916908min
# 0.885791389677
# {'alpha': 0.0028480358684358021}
# r2: 0.917501054923
# RMSLE: 0.114863548826
# [CV 32]
# Total time used: 0.177086031437min
# 0.886508826816
# {'alpha': 0.0049770235643321137}
# r2: 0.870140519702
# RMSLE: 0.133547232238
# [CV 33]
# Total time used: 0.173993368944min
# 0.886192866543
# {'alpha': 0.0021544346900318843}
# r2: 0.457997415089
# RMSLE: 0.149286084343
# [CV 34]
# Total time used: 0.177392748992min
# 0.885613152959
# {'alpha': 0.0043287612810830618}
# r2: 0.880004532444
# RMSLE: 0.120992646854
# [CV 35]
# Total time used: 0.175346199671min
# 0.886889167689
# {'alpha': 0.0049770235643321137}
# r2: 0.899419195579
# RMSLE: 0.126634708232
# [CV 36]
# Total time used: 0.177642699083min
# 0.888263670773
# {'alpha': 4.0370172585965579e-06}
# r2: 0.896218771794
# RMSLE: 0.116329256453
# [CV 37]
# Total time used: 0.180242236455min
# 0.886546441106
# {'alpha': 0.0024770763559917113}
# r2: 0.891956101415
# RMSLE: 0.129330443355
# [CV 38]
# Total time used: 0.180432450771min
# 0.887939679248
# {'alpha': 0.0037649358067924675}
# r2: 0.929045234088
# RMSLE: 0.105610397427
# [CV 39]
# Total time used: 0.178867530823min
# 0.886188098271
# {'alpha': 0.006579332246575682}
# r2: 0.67438314754
# RMSLE: 0.159758958144
# [CV 40]
# Total time used: 0.179321181774min
# 0.886359656107
# {'alpha': 0.0028480358684358021}
# r2: 0.562215538985
# RMSLE: 0.15304180065
# [CV 41]
# Total time used: 0.17405226628min
# 0.889618471883
# {'alpha': 0.0014174741629268048}
# r2: 0.897721956116
# RMSLE: 0.119627310594
# [CV 42]
# Total time used: 0.178426949183min
# 0.887819743272
# {'alpha': 0.0043287612810830618}
# r2: 0.888064667121
# RMSLE: 0.126324333395
# [CV 43]
# Total time used: 0.175116415819min
# 0.887982304609
# {'alpha': 0.0021544346900318843}
# r2: 0.918244509832
# RMSLE: 0.116959390453
# [CV 44]
# Total time used: 0.173816132545min
# 0.886989944162
# {'alpha': 0.0037649358067924675}
# r2: 0.907483594515
# RMSLE: 0.114372143363
# [CV 45]
# Total time used: 0.176984532674min
# 0.887686390094
# {'alpha': 0.0016297508346206451}
# r2: 0.905030650035
# RMSLE: 0.131741750466
# [CV 46]
# Total time used: 0.181924800078min
# 0.88631820941
# {'alpha': 0.0037649358067924675}
# r2: 0.554644681937
# RMSLE: 0.158722413094
# [CV 47]
# Total time used: 0.172143316269min
# 0.886948140957
# {'alpha': 0.0043287612810830618}
# r2: 0.804741528663
# RMSLE: 0.14412072139
# [CV 48]
# Total time used: 0.175257432461min
# 0.888441690273
# {'alpha': 0.0024770763559917113}
# r2: 0.770934552566
# RMSLE: 0.139774224582
# [CV 49]
# Total time used: 0.180335581303min
# 0.888428120724
# {'alpha': 0.0043287612810830618}
# r2: 0.903362395172
# RMSLE: 0.120222610029
# [CV 50]
# Total time used: 0.175376749039min
# 0.887060448978
# {'alpha': 0.0037649358067924675}
# r2: 0.922639454905
# RMSLE: 0.106370799667
# [CV 51]
# Total time used: 0.176925114791min
# 0.886226586733
# {'alpha': 0.0057223676593502202}
# r2: 0.914381736766
# RMSLE: 0.110098872471
# [CV 52]
# Total time used: 0.175352414449min
# 0.886113647521
# {'alpha': 0.0043287612810830618}
# r2: 0.910617410749
# RMSLE: 0.133269936501
# [CV 53]
# Total time used: 0.176831948757min
# 0.887988139226
# {'alpha': 0.0057223676593502202}
# r2: 0.91672965512
# RMSLE: 0.12395694648
# [CV 54]
# Total time used: 0.176787734032min
# 0.88769019044
# {'alpha': 0.0032745491628777285}
# r2: 0.906687288718
# RMSLE: 0.125239051126
# [CV 55]
# Total time used: 0.174874349435min
# 0.886214438105
# {'alpha': 3.5111917342151275e-06}
# r2: 0.712910537014
# RMSLE: 0.136568714836
# [CV 56]
# Total time used: 0.17853483359min
# 0.886013200917
# {'alpha': 0.0075646332755462909}
# r2: 0.78567547325
# RMSLE: 0.13686104217
# [CV 57]
# Total time used: 0.179102186362min
# 0.885719986619
# {'alpha': 0.00013219411484660288}
# r2: 0.916371095386
# RMSLE: 0.110961337646
# [CV 58]
# Total time used: 0.17715088129min
# 0.889591034571
# {'alpha': 0.0037649358067924675}
# r2: 0.893815566583
# RMSLE: 0.130085302377
# [CV 59]
# Total time used: 0.175640400251min
# 0.887731555367
# {'alpha': 0.0021544346900318843}
# r2: 0.560648967585
# RMSLE: 0.167195097873
# [CV 60]
# Total time used: 0.178041863441min
# 0.887900808655
# {'alpha': 0.0012328467394420659}
# r2: 0.856244182275
# RMSLE: 0.120981374793
# [CV 61]
# Total time used: 0.179144314925min
# 0.887508790176
# {'alpha': 0.00053366992312063122}
# r2: 0.859056806005
# RMSLE: 0.135620759844
# [CV 62]
# Total time used: 0.173400449753min
# 0.884750050817
# {'alpha': 0.0075646332755462909}
# r2: 0.884911236255
# RMSLE: 0.126320416556
# [CV 63]
# Total time used: 0.177532748381min
# 0.88742662199
# {'alpha': 8.6974900261778344e-05}
# r2: 0.767459962957
# RMSLE: 0.14228996581
# [CV 64]
# Total time used: 0.175194084644min
# 0.887135501835
# {'alpha': 0.0032745491628777285}
# r2: 0.878228068782
# RMSLE: 0.123187025353
# [CV 65]
# Total time used: 0.177054385344min
# 0.888956963336
# {'alpha': 0.0032745491628777285}
# r2: 0.902052647691
# RMSLE: 0.1354722031
# [CV 66]
# Total time used: 0.17937921683min
# 0.887321081868
# {'alpha': 0.00053366992312063122}
# r2: 0.888665966826
# RMSLE: 0.124660950745
# [CV 67]
# Total time used: 0.176917815208min
# 0.885509493707
# {'alpha': 0.0043287612810830618}
# r2: 0.860589154374
# RMSLE: 0.118570571323
# [CV 68]
# Total time used: 0.175433464845min
# 0.889669073088
# {'alpha': 0.0021544346900318843}
# r2: 0.621046166035
# RMSLE: 0.153829523251
# [CV 69]
# Total time used: 0.175274399916min
# 0.886064864516
# {'alpha': 0.0012328467394420659}
# r2: 0.907346897466
# RMSLE: 0.119001987101
# [CV 70]
# Total time used: 0.175430981318min
# 0.887526483429
# {'alpha': 0.0075646332755462909}
# r2: 0.893490444406
# RMSLE: 0.127417843754
# [CV 71]
# Total time used: 0.180808317661min
# 0.888897684392
# {'alpha': 0.0028480358684358021}
# r2: 0.868923948013
# RMSLE: 0.122982535067
# [CV 72]
# Total time used: 0.175928632418min
# 0.885618222063
# {'alpha': 0.0014174741629268048}
# r2: 0.861071199953
# RMSLE: 0.119969578963
# [CV 73]
# Total time used: 0.176902683576min
# 0.88751324524
# {'alpha': 0.0057223676593502202}
# r2: 0.778242683982
# RMSLE: 0.159936811507
# [CV 74]
# Total time used: 0.178637917837min
# 0.887112970828
# {'alpha': 0.0037649358067924675}
# r2: 0.908794879146
# RMSLE: 0.112100121423
# [CV 75]
# Total time used: 0.173970282078min
# 0.888549760482
# {'alpha': 0.0057223676593502202}
# r2: 0.912759325024
# RMSLE: 0.118294878629
# [CV 76]
# Total time used: 0.178709634145min
# 0.886968272417
# {'alpha': 0.0012328467394420659}
# r2: 0.870349144321
# RMSLE: 0.135143911614
# [CV 77]
# Total time used: 0.176909784476min
# 0.887910501532
# {'alpha': 0.0043287612810830618}
# r2: 0.895240439184
# RMSLE: 0.127104225384
# [CV 78]
# Total time used: 0.177116815249min
# 0.888242687899
# {'alpha': 0.0057223676593502202}
# r2: 0.909936342384
# RMSLE: 0.114817887498
# [CV 79]
# Total time used: 0.175302533309min
# 0.885160113902
# {'alpha': 0.0049770235643321137}
# r2: 0.901709514666
# RMSLE: 0.112702416266
# [CV 80]
# Total time used: 0.178233917554min
# 0.885898960638
# {'alpha': 1.7475284000076829e-06}
# r2: 0.909971275461
# RMSLE: 0.124461319985
# [CV 81]
# Total time used: 0.181750452518min
# 0.885707797044
# {'alpha': 0.006579332246575682}
# r2: 0.894983804587
# RMSLE: 0.113318129866
# [CV 82]
# Total time used: 0.17194763422min
# 0.885701158418
# {'alpha': 0.0016297508346206451}
# r2: 0.905400125483
# RMSLE: 0.116546334087
# [CV 83]
# Total time used: 0.181798080603min
# 0.885710396765
# {'alpha': 0.0028480358684358021}
# r2: 0.887304259556
# RMSLE: 0.125818500956
# [CV 84]
# Total time used: 0.180847100417min
# 0.886545962615
# {'alpha': 0.00011497569953977356}
# r2: 0.907766448455
# RMSLE: 0.109283234226
# [CV 85]
# Total time used: 0.183432817459min
# 0.886810029365
# {'alpha': 0.0049770235643321137}
# r2: 0.880027337836
# RMSLE: 0.12361982579
# [CV 86]
# Total time used: 0.185517032941min
# 0.88596784102
# {'alpha': 0.0021544346900318843}
# r2: 0.66709411779
# RMSLE: 0.16388267927
# [CV 87]
# Total time used: 0.178961952527min
# 0.885520861956
# {'alpha': 0.0043287612810830618}
# r2: 0.80877140415
# RMSLE: 0.137478164072
# [CV 88]
# Total time used: 0.175268681844min
# 0.888035385613
# {'alpha': 0.0032745491628777285}
# r2: 0.887923897648
# RMSLE: 0.128019345233
# [CV 89]
# Total time used: 0.17559595108min
# 0.888157681554
# {'alpha': 0.006579332246575682}
# r2: 0.763896010246
# RMSLE: 0.139428429605
# [CV 90]
# Total time used: 0.179701217016min
# 0.888415924648
# {'alpha': 0.00013219411484660288}
# r2: 0.787384434983
# RMSLE: 0.147152973857
# [CV 91]
# Total time used: 0.180124100049min
# 0.886663939565
# {'alpha': 0.0028480358684358021}
# r2: 0.885857777602
# RMSLE: 0.132717157905
# [CV 92]
# Total time used: 0.172643665473min
# 0.885842302057
# {'alpha': 0.0010722672220103231}
# r2: 0.799962947847
# RMSLE: 0.146282933558
# [CV 93]
# Total time used: 0.177707580725min
# 0.886194598234
# {'alpha': 5.7223676593502203e-05}
# r2: 0.775235036911
# RMSLE: 0.136140325169
# [CV 94]
# Total time used: 0.178949332237min
# 0.886261073951
# {'alpha': 0.0049770235643321137}
# r2: 0.913944530537
# RMSLE: 0.114278262396
# [CV 95]
# Total time used: 0.175619133313min
# 0.887268509584
# {'alpha': 0.00081113083078968723}
# r2: 0.853626010915
# RMSLE: 0.130859982552
# [CV 96]
# Total time used: 0.17528286775min
# 0.886139386827
# {'alpha': 0.006579332246575682}
# r2: 0.902380114172
# RMSLE: 0.119402577299
# [CV 97]
# Total time used: 0.17734134992min
# 0.88710148727
# {'alpha': 0.0049770235643321137}
# r2: 0.885962067345
# RMSLE: 0.134811915939
# [CV 98]
# Total time used: 0.178543130557min
# 0.886789632663
# {'alpha': 0.0057223676593502202}
# r2: 0.598994563234
# RMSLE: 0.151751605772
# [CV 99]
# Total time used: 0.174298600356min
# 0.885732119159
# {'alpha': 6.1359072734131755e-06}
# r2: 0.861723579075
# RMSLE: 0.126057867904
# Done training and predicting.
# In total 47 contributes to ensemble out of 100

# %%
for i in all_prediction:
    plt.plot(range(len(i)), i, 'o')
