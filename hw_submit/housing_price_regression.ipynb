# %%
# Adding needed libraries and reading data
import pandas as pd
import numpy as np
from scipy.stats import skew
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
# rcParams['figure.figsize'] = 22, 4
import time

import seaborn as sns
from sklearn import metrics, ensemble, tree, linear_model
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV, train_test_split, ShuffleSplit, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.utils import shuffle

# import xgboost as xgb

from fancyimpute import SimpleFill, BiScaler, KNN, NuclearNormMinimization, SoftImpute, MICE


# Load data
train_df = pd.read_csv('./data/train.csv')
test_df = pd.read_csv('./data/test.csv')
train_y = train_df.pop('SalePrice') # take out y value
test_id = test_df.pop('Id') # for writing submission file
# also remove id column from train as it will not be used
train_df.drop('Id', axis = 1, inplace=True)
# Out:
# Using cuDNN version 5105 on context None
# Mapped name None to device cuda: GeForce GTX 1080 (0000:01:00.0)

# %%
train_df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig      ...       ScreenPorch PoolArea PoolQC  \
# 0         Lvl    AllPub    Inside      ...                 0        0    NaN
# 1         Lvl    AllPub       FR2      ...                 0        0    NaN
# 2         Lvl    AllPub    Inside      ...                 0        0    NaN
# 3         Lvl    AllPub    Corner      ...                 0        0    NaN
# 4         Lvl    AllPub       FR2      ...                 0        0    NaN
#
#   Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0   NaN         NaN       0       2    2008        WD         Normal
# 1   NaN         NaN       0       5    2007        WD         Normal
# 2   NaN         NaN       0       9    2008        WD         Normal
# 3   NaN         NaN       0       2    2006        WD        Abnorml
# 4   NaN         NaN       0      12    2008        WD         Normal
#
# [5 rows x 79 columns]

# %%
print train_df.shape
print test_df.shape
# Out:
# (1460, 79)
# (1459, 79)

# %%
# check number of nan in both train and test for each columns
def check_null(df):
    null_check = df.isnull().sum(axis=0)
    null = null_check[null_check!=0]
    null_df = df.isnull()
    return null, null_df
train_null, _ = check_null(train_df)
test_null, _ = check_null(test_df)
# print ">>>null value in train:\n", train_null
# print "\n>>>null value in test:\n", test_null

# %%
# train_null.plot.bar()

# %%
# test_null.plot.bar()

# %%
# get rid off columns with missing values more than 15%
drop_cols1 = [train_null.index[i] for i in range(train_null.shape[0]) if train_null.values[i] > train_df.shape[0]*0.15]
drop_cols2 = [test_null.index[i] for i in range(test_null.shape[0]) if test_null.values[i] > test_df.shape[0]*0.15]
drop_cols = list(set(drop_cols1+drop_cols2))
print drop_cols
# Out:
# ['Fence', 'LotFrontage', 'MiscFeature', 'Alley', 'FireplaceQu', 'PoolQC']

# %%
# finish drop and start impute rest missing data
train_df.drop(drop_cols, axis = 1, inplace=True)
test_df.drop(drop_cols, axis = 1, inplace=True)

# after dropping selected columns, we want to impute which requires
# data to be numeric value, so we proceed to convert categorical data
# but this conversion erases nan, so here we record where the nan is
_, train_nulls = check_null(train_df)
_, test_nulls = check_null(test_df)

# %%
# convert object to categorical value first
# record what columns are categorical and numeric columns
obj_columns = train_df.select_dtypes(['object']).columns
num_columns = list(set(train_df.columns)-set(obj_columns))

# just in case test set has more categories than train, concatenate them first for conversion
train_df.loc[:, 'temp'] = 'train'
test_df.loc[:, 'temp'] = 'test'
combined_df = pd.concat([train_df, test_df])

for col in obj_columns:
    combined_df[col] = combined_df[col].astype('category')
# now convert train set
combined_df[obj_columns] = combined_df[obj_columns].apply(lambda x: x.cat.codes)

# now split back to train and test
train_df = combined_df[combined_df['temp']=='train'].drop(['temp'], axis=1)
test_df = combined_df[combined_df['temp']=='test'].drop(['temp'], axis=1)

# %%
# get the nan back
train_df[train_nulls] = np.nan
test_df[test_nulls] = np.nan

# %%
rcParams['figure.figsize'] = 20, 20
# take a look of each variable vs y
f, axes = plt.subplots(5,7)
n_iter = 0
for i in range(5):
    for j in range(7):
        sns.regplot(x=train_df[num_columns[n_iter]], y=train_y,ax=axes[i][j])
        n_iter += 1

# %%
# outliers
# drop outliers
outliers_id = np.array([524, 1299])
outliers_id = outliers_id - 1 # id starts with 1, index starts with 0
train_df.drop(outliers_id, inplace=True)
train_y.drop(outliers_id, inplace=True)

# %%
# impute missing data

# train_df = SimpleFill().complete(train_df)
# train_df = SoftImpute().complete(train_df)
# train_df = KNN(k=5).complete(train_df)
train_df[train_df.columns] = MICE().complete(train_df.values)

# test_df = SimpleFill().complete(test_df)
# test_df = SoftImpute().complete(test_df)
# test_df = KNN(k=5).complete(test_df)
test_df[test_df.columns] = MICE().complete(test_df.values)

train_df = pd.DataFrame(train_df, columns=train_df.columns)
test_df = pd.DataFrame(test_df, columns=test_df.columns)
# Out:
# [MICE] Completing matrix with shape (1458, 73)
# [MICE] Starting imputation round 1/110, elapsed time 0.001
# [MICE] Starting imputation round 2/110, elapsed time 0.532
# [MICE] Starting imputation round 3/110, elapsed time 0.541
# [MICE] Starting imputation round 4/110, elapsed time 0.555
# [MICE] Starting imputation round 5/110, elapsed time 0.564
# [MICE] Starting imputation round 6/110, elapsed time 0.574
# [MICE] Starting imputation round 7/110, elapsed time 0.584
# [MICE] Starting imputation round 8/110, elapsed time 0.594
# [MICE] Starting imputation round 9/110, elapsed time 0.604
# [MICE] Starting imputation round 10/110, elapsed time 0.614
# [MICE] Starting imputation round 11/110, elapsed time 0.624
# [MICE] Starting imputation round 12/110, elapsed time 0.633
# [MICE] Starting imputation round 13/110, elapsed time 0.647
# [MICE] Starting imputation round 14/110, elapsed time 0.657
# [MICE] Starting imputation round 15/110, elapsed time 0.667
# [MICE] Starting imputation round 16/110, elapsed time 0.677
# [MICE] Starting imputation round 17/110, elapsed time 0.687
# [MICE] Starting imputation round 18/110, elapsed time 0.697
# [MICE] Starting imputation round 19/110, elapsed time 0.707
# [MICE] Starting imputation round 20/110, elapsed time 0.717
# [MICE] Starting imputation round 21/110, elapsed time 0.727
# [MICE] Starting imputation round 22/110, elapsed time 0.741
# [MICE] Starting imputation round 23/110, elapsed time 0.755
# [MICE] Starting imputation round 24/110, elapsed time 0.766
# [MICE] Starting imputation round 25/110, elapsed time 0.776
# [MICE] Starting imputation round 26/110, elapsed time 0.786
# [MICE] Starting imputation round 27/110, elapsed time 0.796
# [MICE] Starting imputation round 28/110, elapsed time 0.805
# [MICE] Starting imputation round 29/110, elapsed time 0.815
# [MICE] Starting imputation round 30/110, elapsed time 0.826
# [MICE] Starting imputation round 31/110, elapsed time 0.836
# [MICE] Starting imputation round 32/110, elapsed time 0.845
# [MICE] Starting imputation round 33/110, elapsed time 0.855
# [MICE] Starting imputation round 34/110, elapsed time 0.865
# [MICE] Starting imputation round 35/110, elapsed time 0.875
# [MICE] Starting imputation round 36/110, elapsed time 0.885
# [MICE] Starting imputation round 37/110, elapsed time 0.895
# [MICE] Starting imputation round 38/110, elapsed time 0.905
# [MICE] Starting imputation round 39/110, elapsed time 0.915
# [MICE] Starting imputation round 40/110, elapsed time 0.924
# [MICE] Starting imputation round 41/110, elapsed time 0.934
# [MICE] Starting imputation round 42/110, elapsed time 0.949
# [MICE] Starting imputation round 43/110, elapsed time 0.962
# [MICE] Starting imputation round 44/110, elapsed time 0.972
# [MICE] Starting imputation round 45/110, elapsed time 0.983
# [MICE] Starting imputation round 46/110, elapsed time 0.993
# [MICE] Starting imputation round 47/110, elapsed time 1.003
# [MICE] Starting imputation round 48/110, elapsed time 1.013
# [MICE] Starting imputation round 49/110, elapsed time 1.023
# [MICE] Starting imputation round 50/110, elapsed time 1.033
# [MICE] Starting imputation round 51/110, elapsed time 1.042
# [MICE] Starting imputation round 52/110, elapsed time 1.052
# [MICE] Starting imputation round 53/110, elapsed time 1.062
# [MICE] Starting imputation round 54/110, elapsed time 1.072
# [MICE] Starting imputation round 55/110, elapsed time 1.082
# [MICE] Starting imputation round 56/110, elapsed time 1.092
# [MICE] Starting imputation round 57/110, elapsed time 1.102
# [MICE] Starting imputation round 58/110, elapsed time 1.112
# [MICE] Starting imputation round 59/110, elapsed time 1.122
# [MICE] Starting imputation round 60/110, elapsed time 1.132
# [MICE] Starting imputation round 61/110, elapsed time 1.142
# [MICE] Starting imputation round 62/110, elapsed time 1.157
# [MICE] Starting imputation round 63/110, elapsed time 1.173
# [MICE] Starting imputation round 64/110, elapsed time 1.184
# [MICE] Starting imputation round 65/110, elapsed time 1.194
# [MICE] Starting imputation round 66/110, elapsed time 1.205
# [MICE] Starting imputation round 67/110, elapsed time 1.215
# [MICE] Starting imputation round 68/110, elapsed time 1.224
# [MICE] Starting imputation round 69/110, elapsed time 1.234
# [MICE] Starting imputation round 70/110, elapsed time 1.244
# [MICE] Starting imputation round 71/110, elapsed time 1.254
# [MICE] Starting imputation round 72/110, elapsed time 1.264
# [MICE] Starting imputation round 73/110, elapsed time 1.275
# [MICE] Starting imputation round 74/110, elapsed time 1.285
# [MICE] Starting imputation round 75/110, elapsed time 1.295
# [MICE] Starting imputation round 76/110, elapsed time 1.306
# [MICE] Starting imputation round 77/110, elapsed time 1.316
# [MICE] Starting imputation round 78/110, elapsed time 1.326
# [MICE] Starting imputation round 79/110, elapsed time 1.337
# [MICE] Starting imputation round 80/110, elapsed time 1.347
# [MICE] Starting imputation round 81/110, elapsed time 1.363
# [MICE] Starting imputation round 82/110, elapsed time 1.374
# [MICE] Starting imputation round 83/110, elapsed time 1.387
# [MICE] Starting imputation round 84/110, elapsed time 1.398
# [MICE] Starting imputation round 85/110, elapsed time 1.408
# [MICE] Starting imputation round 86/110, elapsed time 1.417
# [MICE] Starting imputation round 87/110, elapsed time 1.427
# [MICE] Starting imputation round 88/110, elapsed time 1.437
# [MICE] Starting imputation round 89/110, elapsed time 1.447
# [MICE] Starting imputation round 90/110, elapsed time 1.457
# [MICE] Starting imputation round 91/110, elapsed time 1.467
# [MICE] Starting imputation round 92/110, elapsed time 1.477
# [MICE] Starting imputation round 93/110, elapsed time 1.487
# [MICE] Starting imputation round 94/110, elapsed time 1.497
# [MICE] Starting imputation round 95/110, elapsed time 1.507
# [MICE] Starting imputation round 96/110, elapsed time 1.516
# [MICE] Starting imputation round 97/110, elapsed time 1.526
# [MICE] Starting imputation round 98/110, elapsed time 1.536
# [MICE] Starting imputation round 99/110, elapsed time 1.546
# [MICE] Starting imputation round 100/110, elapsed time 1.556
# [MICE] Starting imputation round 101/110, elapsed time 1.572
# [MICE] Starting imputation round 102/110, elapsed time 1.585
# [MICE] Starting imputation round 103/110, elapsed time 1.596
# [MICE] Starting imputation round 104/110, elapsed time 1.606
# [MICE] Starting imputation round 105/110, elapsed time 1.616
# [MICE] Starting imputation round 106/110, elapsed time 1.629
# [MICE] Starting imputation round 107/110, elapsed time 1.641
# [MICE] Starting imputation round 108/110, elapsed time 1.708
# [MICE] Starting imputation round 109/110, elapsed time 1.756
# [MICE] Starting imputation round 110/110, elapsed time 1.804
# [MICE] Completing matrix with shape (1459, 73)
# [MICE] Starting imputation round 1/110, elapsed time 0.001
# [MICE] Starting imputation round 2/110, elapsed time 0.022
# [MICE] Starting imputation round 3/110, elapsed time 0.043
# [MICE] Starting imputation round 4/110, elapsed time 0.063
# [MICE] Starting imputation round 5/110, elapsed time 0.084
# [MICE] Starting imputation round 6/110, elapsed time 0.104
# [MICE] Starting imputation round 7/110, elapsed time 0.124
# [MICE] Starting imputation round 8/110, elapsed time 0.145
# [MICE] Starting imputation round 9/110, elapsed time 0.181
# [MICE] Starting imputation round 10/110, elapsed time 0.202
# [MICE] Starting imputation round 11/110, elapsed time 0.222
# [MICE] Starting imputation round 12/110, elapsed time 0.242
# [MICE] Starting imputation round 13/110, elapsed time 0.263
# [MICE] Starting imputation round 14/110, elapsed time 0.283
# [MICE] Starting imputation round 15/110, elapsed time 0.304
# [MICE] Starting imputation round 16/110, elapsed time 0.328
# [MICE] Starting imputation round 17/110, elapsed time 0.349
# [MICE] Starting imputation round 18/110, elapsed time 0.369
# [MICE] Starting imputation round 19/110, elapsed time 0.406
# [MICE] Starting imputation round 20/110, elapsed time 0.427
# [MICE] Starting imputation round 21/110, elapsed time 0.447
# [MICE] Starting imputation round 22/110, elapsed time 0.471
# [MICE] Starting imputation round 23/110, elapsed time 0.492
# [MICE] Starting imputation round 24/110, elapsed time 0.512
# [MICE] Starting imputation round 25/110, elapsed time 0.540
# [MICE] Starting imputation round 26/110, elapsed time 0.594
# [MICE] Starting imputation round 27/110, elapsed time 0.642
# [MICE] Starting imputation round 28/110, elapsed time 0.663
# [MICE] Starting imputation round 29/110, elapsed time 0.684
# [MICE] Starting imputation round 30/110, elapsed time 0.704
# [MICE] Starting imputation round 31/110, elapsed time 0.725
# [MICE] Starting imputation round 32/110, elapsed time 0.745
# [MICE] Starting imputation round 33/110, elapsed time 0.765
# [MICE] Starting imputation round 34/110, elapsed time 0.794
# [MICE] Starting imputation round 35/110, elapsed time 0.832
# [MICE] Starting imputation round 36/110, elapsed time 0.915
# [MICE] Starting imputation round 37/110, elapsed time 0.996
# [MICE] Starting imputation round 38/110, elapsed time 1.035
# [MICE] Starting imputation round 39/110, elapsed time 1.057
# [MICE] Starting imputation round 40/110, elapsed time 1.077
# [MICE] Starting imputation round 41/110, elapsed time 1.097
# [MICE] Starting imputation round 42/110, elapsed time 1.135
# [MICE] Starting imputation round 43/110, elapsed time 1.156
# [MICE] Starting imputation round 44/110, elapsed time 1.177
# [MICE] Starting imputation round 45/110, elapsed time 1.197
# [MICE] Starting imputation round 46/110, elapsed time 1.217
# [MICE] Starting imputation round 47/110, elapsed time 1.238
# [MICE] Starting imputation round 48/110, elapsed time 1.258
# [MICE] Starting imputation round 49/110, elapsed time 1.293
# [MICE] Starting imputation round 50/110, elapsed time 1.329
# [MICE] Starting imputation round 51/110, elapsed time 1.370
# [MICE] Starting imputation round 52/110, elapsed time 1.391
# [MICE] Starting imputation round 53/110, elapsed time 1.412
# [MICE] Starting imputation round 54/110, elapsed time 1.438
# [MICE] Starting imputation round 55/110, elapsed time 1.461
# [MICE] Starting imputation round 56/110, elapsed time 1.483
# [MICE] Starting imputation round 57/110, elapsed time 1.506
# [MICE] Starting imputation round 58/110, elapsed time 1.528
# [MICE] Starting imputation round 59/110, elapsed time 1.550
# [MICE] Starting imputation round 60/110, elapsed time 1.582
# [MICE] Starting imputation round 61/110, elapsed time 1.616
# [MICE] Starting imputation round 62/110, elapsed time 1.638
# [MICE] Starting imputation round 63/110, elapsed time 1.660
# [MICE] Starting imputation round 64/110, elapsed time 1.682
# [MICE] Starting imputation round 65/110, elapsed time 1.706
# [MICE] Starting imputation round 66/110, elapsed time 1.729
# [MICE] Starting imputation round 67/110, elapsed time 1.754
# [MICE] Starting imputation round 68/110, elapsed time 1.776
# [MICE] Starting imputation round 69/110, elapsed time 1.815
# [MICE] Starting imputation round 70/110, elapsed time 1.847
# [MICE] Starting imputation round 71/110, elapsed time 1.870
# [MICE] Starting imputation round 72/110, elapsed time 1.890
# [MICE] Starting imputation round 73/110, elapsed time 1.911
# [MICE] Starting imputation round 74/110, elapsed time 1.931
# [MICE] Starting imputation round 75/110, elapsed time 1.951
# [MICE] Starting imputation round 76/110, elapsed time 1.972
# [MICE] Starting imputation round 77/110, elapsed time 1.992
# [MICE] Starting imputation round 78/110, elapsed time 2.013
# [MICE] Starting imputation round 79/110, elapsed time 2.065
# [MICE] Starting imputation round 80/110, elapsed time 2.087
# [MICE] Starting imputation round 81/110, elapsed time 2.108
# [MICE] Starting imputation round 82/110, elapsed time 2.131
# [MICE] Starting imputation round 83/110, elapsed time 2.151
# [MICE] Starting imputation round 84/110, elapsed time 2.171
# [MICE] Starting imputation round 85/110, elapsed time 2.192
# [MICE] Starting imputation round 86/110, elapsed time 2.212
# [MICE] Starting imputation round 87/110, elapsed time 2.236
# [MICE] Starting imputation round 88/110, elapsed time 2.257
# [MICE] Starting imputation round 89/110, elapsed time 2.297
# [MICE] Starting imputation round 90/110, elapsed time 2.349
# [MICE] Starting imputation round 91/110, elapsed time 2.372
# [MICE] Starting imputation round 92/110, elapsed time 2.392
# [MICE] Starting imputation round 93/110, elapsed time 2.413
# [MICE] Starting imputation round 94/110, elapsed time 2.434
# [MICE] Starting imputation round 95/110, elapsed time 2.454
# [MICE] Starting imputation round 96/110, elapsed time 2.474
# [MICE] Starting imputation round 97/110, elapsed time 2.495
# [MICE] Starting imputation round 98/110, elapsed time 2.535
# [MICE] Starting imputation round 99/110, elapsed time 2.556
# [MICE] Starting imputation round 100/110, elapsed time 2.576
# [MICE] Starting imputation round 101/110, elapsed time 2.596
# [MICE] Starting imputation round 102/110, elapsed time 2.617
# [MICE] Starting imputation round 103/110, elapsed time 2.637
# [MICE] Starting imputation round 104/110, elapsed time 2.657
# [MICE] Starting imputation round 105/110, elapsed time 2.678
# [MICE] Starting imputation round 106/110, elapsed time 2.698
# [MICE] Starting imputation round 107/110, elapsed time 2.719
# [MICE] Starting imputation round 108/110, elapsed time 2.759
# [MICE] Starting imputation round 109/110, elapsed time 2.780
# [MICE] Starting imputation round 110/110, elapsed time 2.801

# %%
# Our SalesPrice is skewed right (check plot below) 
rcParams['figure.figsize'] = 8, 5
ax = sns.distplot(train_y)

# %%
## we can log transform y value
rcParams['figure.figsize'] = 8, 5
ax = sns.distplot(np.log1p(train_y))
train_y = np.log1p(train_y)

# %%
# Similarly, look at other numeric features
rcParams['figure.figsize'] = 20, 20
# take a look of each variable vs y
print "number of numeric columns: ", len(num_columns)
f, axes = plt.subplots(5,7)
n_iter = 0
for i in range(5):
    for j in range(7):
        sns.distplot(train_df[num_columns[n_iter]],ax=axes[i][j])
        n_iter += 1
# Out:
# number of numeric columns:  35

# %% [markdown]
# ### Skewness

# %%
# compute skewness aloong column/feature
skewed_fts = train_df[num_columns].apply(lambda x: skew(x), axis=0) 
skewed_fts = skewed_fts[np.abs(skewed_fts) > 0.75]
skewed_fts = skewed_fts.index

train_df[skewed_fts] = np.log1p(train_df[skewed_fts])
test_df[skewed_fts] = np.log1p(test_df[skewed_fts])
# now take a look again
f, axes = plt.subplots(5,7)
n_iter = 0
for i in range(5):
    for j in range(7):
        sns.distplot(train_df[num_columns[n_iter]],ax=axes[i][j])
        n_iter += 1

# %%
# Standarization
# fisrt option: standarize non-categoorical values
# std_features = list(set(train_df.columns)-set(obj_columns))
# ss = StandardScaler(copy=True, with_mean=True, with_std=True)
# train_df[std_features] = ss.fit_transform(train_df[std_features])
# test_df[std_features] = ss.transform(test_df[std_features])

# second option: standarize all values
ss = StandardScaler(copy=True, with_mean=True, with_std=True)
train_df[train_df.columns] = ss.fit_transform(train_df)
test_df[test_df.columns] = ss.transform(test_df)

# %%
# train_df[num_columns].describe()

# %%
# train_df[num_columns].head()

# %%
rcParams['figure.figsize'] = 20, 20
# take a look of each variable vs y
f, axes = plt.subplots(5,7)
n_iter = 0
for i in range(5):
    for j in range(7):
        sns.regplot(x=train_df[num_columns[n_iter]], y=train_y,ax=axes[i][j])
        n_iter += 1

# %% [markdown]
# ### multicollinearity

# %%
# look at correlations
correlations = train_df.corr()
cor_abs = np.abs(correlations)
cor_pair = cor_abs[(cor_abs>0.5) & (cor_abs != 1)].unstack().dropna().to_dict()
print "Total pair number:", len(correlations)*(len(correlations)-1)/2
cor_sort = sorted(cor_pair, key=cor_pair.get)[::-1]
cor_value = [cor_pair[k] for k in cor_sort]
cor_df = pd.DataFrame({'pair':cor_sort, 'cor': cor_value})
cor_df.drop_duplicates(subset='cor', inplace=True)
print "Correlated pairs(abs>0.5): ", cor_df.shape[0]
cor_df.head(10)
# Out:
# Total pair number: 2628
# Correlated pairs(abs>0.5):  48
#          cor                          pair
# 0   0.887304      (GarageArea, GarageCars)
# 2   0.853926    (Exterior2nd, Exterior1st)
# 4   0.851368    (BsmtFinSF2, BsmtFinType2)
# 6   0.822983     (TotRmsAbvGrd, GrLivArea)
# 8   0.794784      (YearBuilt, GarageYrBlt)
# 10  0.783890       (1stFlrSF, TotalBsmtSF)
# 12  0.780231    (BsmtFinSF1, BsmtFinType1)
# 14  0.680390  (TotRmsAbvGrd, BedroomAbvGr)
# 16  0.652879         (GrLivArea, FullBath)
# 18  0.636755      (ExterQual, KitchenQual)

# %%
ax = sns.pairplot(train_df[['GarageArea', 'GarageCars']])

# %%
# from above we choose some features to discard
cor_freq = pd.DataFrame({'fts': [x for pair in cor_df['pair'].values for x in pair]})
cor_freq['fts'].value_counts().plot(kind='bar', figsize=(8,6))

# %%
# drop some of the features
freq_fts = list(cor_freq['fts'].value_counts()[:10].index)
top_cor = [pair for pair in cor_df['pair'][:10].values]
drop_fts = ['GarageCars', 'Exterior1st', 'BsmtFinType2', 'GarageYrBlt', 'LotFrontage', 'FullBath']

# comment out below if not dropping
# train_df.drop(drop_fts, axis=1, inplace=True)
# test_df.drop(drop_fts, axis=1, inplace=True)

# %% [markdown]
# ### Try PCA

# %%
# due to multicollinearity, perform PCA on dataset and see if result improves
# n_features = train_df.shape[1]
# print "Total number of features before PCA: ", n_features

# pca = PCA(n_features)
# pca.fit_transform(train_df)

# explained = pca.explained_variance_ratio_
# n_use = 60
# print "Covers {} variance".format(sum(explained[:n_use]))

# pca = PCA(n_use)
# train_df = pca.fit_transform(train_df)
# test_df = pca.transform(test_df)

# %% [markdown]
# ### train GB regressor

# %%
def find_params(train_X, train_Y, test_X, params_found=False, verbose=False):
    if not params_found:
        print "Finding params ..."
        t1 = time.time()
        param_grid = {'learning_rate':[0.1, 0.01, 0.001],
                      'max_depth': [3,4,6],
                      'min_samples_leaf': [3,5,9,17],
                      'max_features': [0.05, 0.1, 0.3, 0.5]}
        est = ensemble.GradientBoostingRegressor(loss='huber', n_estimators=5000)
        gs_cv = GridSearchCV(est, param_grid, cv=ShuffleSplit(n_splits=4, test_size=0.25, random_state=42),
                             n_jobs=4).fit(train_X, train_Y)
        t2 = time.time()

        best_est = gs_cv.best_estimator_
        
        print "Total time used: {0:.2f} min".format((t2-t1)/60.)
        print gs_cv.best_score_
        print gs_cv.best_params_
        return gs_cv.best_params_, best_est.feature_importances_
    else:
        print "Use previous found best params."
    
bg_param, bg_fts = find_params(train_df.values, train_y.values, test_df.values, params_found=False, verbose=True)
# find_params(train_df, train_y.values, test_df, params_found=True, verbose=True)
# Out:
# Finding params ...
# Total time used: 15.66 min
# 0.913118521223
# {'max_features': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_leaf': 3}

# %%
coef = pd.Series(bg_fts, index=train_df.columns)
imp_coef = pd.concat([coef.sort_values().head(5), coef.sort_values().tail(10)])
imp_coef.plot(kind='barh', fontsize=25)

# %%
# def train_predict(train_X, train_Y, test_X, ensemble_tol=None, verbose=False):
#     n_cv = 500
#     prediction = []
#     n_tol = 0
#     for n_i in range(n_cv):
#         if verbose:
#             print "[CV {}]".format(n_i)
#         x_train, x_val, y_train, y_val = train_test_split(train_X, train_Y, test_size=0.2, random_state=42+n_i)
#         bst = ensemble.GradientBoostingRegressor(n_estimators=8000, max_features=bg_param['max_features'], 
#                                                  loss='huber', 
#                                                  learning_rate=bg_param['learning_rate'], 
#                                                  max_depth=bg_param['max_depth'], 
#                                                  min_samples_leaf=bg_param['min_samples_leaf'],
#                                                  random_state=None)
#         bst.fit(x_train, y_train)
#         preds = bst.predict(x_val)
        
#         preds = np.expm1(preds)
#         y_val = np.expm1(y_val)
#         r2 = metrics.r2_score(y_val, preds)
#         rmsle = np.sqrt(sum((np.log(np.array(preds)+1)-np.log(np.array(y_val)+1))**2)/len(preds))
#         print "r2:", r2
#         print "RMSLE:", rmsle
        
#         prediction_i = bst.predict(test_X)
        
#         if ensemble_tol:
#             if rmsle <= ensemble_tol:
#                 prediction.append(prediction_i)
#                 n_tol += 1
#         else:
#             prediction.append(prediction_i)
#     print "Done training and predicting."
#     if ensemble_tol:
#         print "In total {} contributes to ensemble out of {}".format(n_tol, n_cv)
    
#     prediction = np.array(prediction)
#     ensemble_result = []
#     n, m = prediction.shape
#     p_std = np.std(prediction, axis=0) # along columns
#     p_mean = np.mean(prediction, axis=0)
#     for i in range(m):
#         p_i = prediction[:,i]
#         select_i = p_i[np.abs(p_i-p_mean[i]) < 1.*p_std[i]]
#         ensemble_result.append(np.mean(select_i))
#     # transform y back to normal scale
#     ensemble_result = np.expm1(ensemble_result)
#     result_df = pd.DataFrame({'Id': test_id, 'SalePrice':ensemble_result})
#     result_df.to_csv('./result/result_gb8k_final1.csv', index=False)
    
#     return prediction

# # e_tol = 0.13
# e_tol = None
# all_prediction = train_predict(train_df.values, train_y.values, test_df.values, ensemble_tol= e_tol, verbose=True)
# # train_predict(train_df, train_y, test_df, verbose=True)

# %%
# for i in all_prediction:
#     plt.plot(range(len(i)), i, 'o')

# %% [markdown]
# ### Try lasso regression

# %%
def find_params(train_X, train_Y, test_X, params_found=False, rd = 42, verbose=False):
    if not params_found:
        print "Finding params ..."
        t1 = time.time()
        param_grid = {'alpha': 10**np.linspace(-6, 0, 100)}
        lasso = linear_model.Lasso(max_iter=50000)
        lasso_cv = GridSearchCV(lasso, param_grid, cv=ShuffleSplit(n_splits=10, test_size=0.2, random_state=rd), 
                                n_jobs=4).fit(train_X, train_Y)
        t2 = time.time()

        cv_df = pd.DataFrame(lasso_cv.cv_results_)
        
        best_lasso = lasso_cv.best_estimator_
        print "Total time used: {0:.2f} min".format((t2-t1)/60.)
        print lasso_cv.best_score_
        print lasso_cv.best_params_
        
        return cv_df, lasso_cv.best_params_['alpha'], best_lasso.coef_
    else:
        print "Use previous found best params."
    
# find_params(train_df.values, train_y.values, test_df.values, params_found=True, verbose=True)
cv_df, best_alpha, coef = find_params(train_df.values, train_y.values, test_df.values, params_found=False, verbose=True)
# Out:
# Finding params ...
# Total time used: 0.35 min
# 0.910735195875
# {'alpha': 0.0014174741629268048}

# %%
# coef = pd.Series(coef, index=train_df.columns)
# imp_coef = pd.concat([coef.sort_values().head(5), coef.sort_values().tail(10)])
# imp_coef.plot(kind='barh', fontsize=25)

# %%
rcParams['figure.figsize'] = 8, 5
plt.plot(cv_df['param_alpha'].apply(lambda x: np.log10(x)), cv_df['mean_train_score'],
         cv_df['param_alpha'].apply(lambda x: np.log10(x)), cv_df['mean_test_score'])
plt.legend(('train', 'validation'), loc='best')

# %%
# def train_predict(train_X, train_Y, test_X, ensemble_tol=None, verbose=False):
#     n_cv = 100
#     prediction = []
#     n_tol = 0
#     for n_i in range(n_cv):
#         if verbose:
#             print "[CV {}]".format(n_i)
#         x_train, x_val, y_train, y_val = train_test_split(train_X, train_Y, test_size=0.2, random_state=42+n_i)

#         _, best_alpha = find_params(train_X, train_Y, test_X, params_found=False, rd=42+n_i, verbose=True)
# #         lm_i = linear_model.LinearRegression()
#         lm_i = linear_model.Lasso(max_iter=50000, alpha=best_alpha)
#         lm_i.fit(x_train, y_train)
#         preds = lm_i.predict(x_val)
        
#         preds = np.expm1(preds)
#         y_val = np.expm1(y_val)
        
#         r2 = metrics.r2_score(y_val, preds)
#         rmsle = np.sqrt(sum((np.log(np.array(preds)+1)-np.log(np.array(y_val)+1))**2)/len(preds))
#         print "r2:", r2
#         print "RMSLE:", rmsle
        
#         prediction_i = lm_i.predict(test_X)
        
#         if ensemble_tol:
#             if rmsle <= ensemble_tol:
#                 prediction.append(prediction_i)
#                 n_tol += 1
#         else:
#             prediction.append(prediction_i)
#     print "Done training and predicting."
#     if ensemble_tol:
#         print "In total {} contributes to ensemble out of {}".format(n_tol, n_cv)
    
#     prediction = np.array(prediction)
#     ensemble_result = []
#     n, m = prediction.shape
#     p_std = np.std(prediction, axis=0) # along columns
#     p_mean = np.mean(prediction, axis=0)
#     for i in range(m):
#         p_i = prediction[:,i]
#         select_i = p_i[np.abs(p_i-p_mean[i]) < 1.*p_std[i]]
#         ensemble_result.append(np.mean(select_i))
#     # transform y back to normal scale
#     ensemble_result = np.expm1(ensemble_result)
#     result_df = pd.DataFrame({'Id': test_id, 'SalePrice':ensemble_result})
#     result_df.to_csv('./result/result_lasso_final1.csv', index=False)
    
#     return prediction

# e_tol = 0.13
# # e_tol = None
# all_prediction = train_predict(train_df.values, train_y.values, test_df.values, ensemble_tol= e_tol, verbose=True)
# # train_predict(train_df, train_y, test_df, verbose=True)

# %%
# for i in all_prediction:
#     plt.plot(range(len(i)), i, 'o')
